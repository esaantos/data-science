# %%
# Formação Cientista de Dados - Fernando Amaral e Jones Granatyr
# Algoritmo Random Forest

# %%
# Importação das bibliotecas
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
# Carregamento da base de dados e criação dos previsores (variáveis independentes - X) e da classe (variável dependente - y)
credito = pd.read_csv('Credit.csv')
credito.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# 1                       2  'female div/dep/mar'          none  ...
# 2                       2         'male single'          none  ...
# 3                       2         'male single'     guarantor  ...
# 4                       3         'male single'          none  ...
#
#     property_magnitude age  other_payment_plans     housing existing_credits  \
# 0        'real estate'  67                 none         own                2
# 1        'real estate'  22                 none         own                1
# 2        'real estate'  49                 none         own                1
# 3     'life insurance'  45                 none  'for free'                1
# 4  'no known property'  53                 none  'for free'                2
#
#                     job num_dependents  own_telephone foreign_worker class
# 0               skilled              1            yes            yes  good
# 1               skilled              1           none            yes   bad
# 2  'unskilled resident'              2           none            yes  good
# 3               skilled              2           none            yes  good
# 4               skilled              2           none            yes   bad
#
# [5 rows x 21 columns]

# %%
previsores = credito.iloc[:,0:20].values
classe = credito.iloc[:,20].values

# %%
# Transformação dos atributos categóricos em atributos numéricos, passando o índice de cada atributo categórico
labelencoder = LabelEncoder()
previsores[:,0] = labelencoder.fit_transform(previsores[:,0])
previsores[:,2] = labelencoder.fit_transform(previsores[:,2])
previsores[:, 3] = labelencoder.fit_transform(previsores[:, 3])
previsores[:, 5] = labelencoder.fit_transform(previsores[:, 5])
previsores[:, 6] = labelencoder.fit_transform(previsores[:, 6])
previsores[:, 8] = labelencoder.fit_transform(previsores[:, 8])
previsores[:, 9] = labelencoder.fit_transform(previsores[:, 9])
previsores[:, 11] = labelencoder.fit_transform(previsores[:, 11])
previsores[:, 13] = labelencoder.fit_transform(previsores[:, 13])
previsores[:, 14] = labelencoder.fit_transform(previsores[:, 14])
previsores[:, 16] = labelencoder.fit_transform(previsores[:, 16])
previsores[:, 18] = labelencoder.fit_transform(previsores[:, 18])
previsores[:, 19] = labelencoder.fit_transform(previsores[:, 19])

# %%
# Divisão da base de dados entre treinamento e teste (30% para testar e 70% para treinar)
X_treinamento, X_teste, y_treinamento, y_teste = train_test_split(previsores,
                                                                  classe,
                                                                  test_size = 0.3,
                                                                  random_state = 0)

# %%
# Criação do modelo, treinamento, obtenção das previsões e da taxa de acerto
floresta = RandomForestClassifier(n_estimators = 200)
floresta.fit(X_treinamento, y_treinamento)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
# Visualização dos atributos principais
floresta.estimators_
#floresta.estimators_[1]
# Out:
# [DecisionTreeClassifier(max_features='auto', random_state=295953058),
#  DecisionTreeClassifier(max_features='auto', random_state=2099122919),
#  DecisionTreeClassifier(max_features='auto', random_state=615417918),
#  DecisionTreeClassifier(max_features='auto', random_state=1792295941),
#  DecisionTreeClassifier(max_features='auto', random_state=1314262550),
#  DecisionTreeClassifier(max_features='auto', random_state=50555120),
#  DecisionTreeClassifier(max_features='auto', random_state=567608061),
#  DecisionTreeClassifier(max_features='auto', random_state=1438483606),
#  DecisionTreeClassifier(max_features='auto', random_state=116037996),
#  DecisionTreeClassifier(max_features='auto', random_state=1311152783),
#  DecisionTreeClassifier(max_features='auto', random_state=1890749666),
#  DecisionTreeClassifier(max_features='auto', random_state=403425433),
#  DecisionTreeClassifier(max_features='auto', random_state=1267449612),
#  DecisionTreeClassifier(max_features='auto', random_state=573111844),
#  DecisionTreeClassifier(max_features='auto', random_state=789977167),
#  DecisionTreeClassifier(max_features='auto', random_state=1024686675),
#  DecisionTreeClassifier(max_features='auto', random_state=950136381),
#  DecisionTreeClassifier(max_features='auto', random_state=1668963588),
#  DecisionTreeClassifier(max_features='auto', random_state=1597891917),
#  DecisionTreeClassifier(max_features='auto', random_state=1450374581),
#  DecisionTreeClassifier(max_features='auto', random_state=844413377),
#  DecisionTreeClassifier(max_features='auto', random_state=1070974255),
#  DecisionTreeClassifier(max_features='auto', random_state=298918702),
#  DecisionTreeClassifier(max_features='auto', random_state=1133152470),
#  DecisionTreeClassifier(max_features='auto', random_state=390383160),
#  DecisionTreeClassifier(max_features='auto', random_state=1667494316),
#  DecisionTreeClassifier(max_features='auto', random_state=419017328),
#  DecisionTreeClassifier(max_features='auto', random_state=1351408520),
#  DecisionTreeClassifier(max_features='auto', random_state=1161555989),
#  DecisionTreeClassifier(max_features='auto', random_state=909392202),
#  DecisionTreeClassifier(max_features='auto', random_state=868065852),
#  DecisionTreeClassifier(max_features='auto', random_state=2025761035),
#  DecisionTreeClassifier(max_features='auto', random_state=1035640299),
#  DecisionTreeClassifier(max_features='auto', random_state=492523485),
#  DecisionTreeClassifier(max_features='auto', random_state=935749269),
#  DecisionTreeClassifier(max_features='auto', random_state=1484695346),
#  DecisionTreeClassifier(max_features='auto', random_state=13440548),
#  DecisionTreeClassifier(max_features='auto', random_state=335337851),
#  DecisionTreeClassifier(max_features='auto', random_state=1820623568),
#  DecisionTreeClassifier(max_features='auto', random_state=735843020),
#  DecisionTreeClassifier(max_features='auto', random_state=451398867),
#  DecisionTreeClassifier(max_features='auto', random_state=972318138),
#  DecisionTreeClassifier(max_features='auto', random_state=2123520935),
#  DecisionTreeClassifier(max_features='auto', random_state=1123863501),
#  DecisionTreeClassifier(max_features='auto', random_state=1655697077),
#  DecisionTreeClassifier(max_features='auto', random_state=1490812224),
#  DecisionTreeClassifier(max_features='auto', random_state=697813988),
#  DecisionTreeClassifier(max_features='auto', random_state=333752224),
#  DecisionTreeClassifier(max_features='auto', random_state=1496712794),
#  DecisionTreeClassifier(max_features='auto', random_state=1291824725),
#  DecisionTreeClassifier(max_features='auto', random_state=227089085),
#  DecisionTreeClassifier(max_features='auto', random_state=2057366976),
#  DecisionTreeClassifier(max_features='auto', random_state=252220147),
#  DecisionTreeClassifier(max_features='auto', random_state=1502978100),
#  DecisionTreeClassifier(max_features='auto', random_state=464296045),
#  DecisionTreeClassifier(max_features='auto', random_state=1543262897),
#  DecisionTreeClassifier(max_features='auto', random_state=325043267),
#  DecisionTreeClassifier(max_features='auto', random_state=1128737440),
#  DecisionTreeClassifier(max_features='auto', random_state=2039685487),
#  DecisionTreeClassifier(max_features='auto', random_state=1059865765),
#  DecisionTreeClassifier(max_features='auto', random_state=1082495523),
#  DecisionTreeClassifier(max_features='auto', random_state=1899241805),
#  DecisionTreeClassifier(max_features='auto', random_state=1479372866),
#  DecisionTreeClassifier(max_features='auto', random_state=1385569117),
#  DecisionTreeClassifier(max_features='auto', random_state=1711050071),
#  DecisionTreeClassifier(max_features='auto', random_state=847163247),
#  DecisionTreeClassifier(max_features='auto', random_state=1967473191),
#  DecisionTreeClassifier(max_features='auto', random_state=1871670230),
#  DecisionTreeClassifier(max_features='auto', random_state=1792046471),
#  DecisionTreeClassifier(max_features='auto', random_state=2088777299),
#  DecisionTreeClassifier(max_features='auto', random_state=338532290),
#  DecisionTreeClassifier(max_features='auto', random_state=1938684045),
#  DecisionTreeClassifier(max_features='auto', random_state=582080139),
#  DecisionTreeClassifier(max_features='auto', random_state=19699425),
#  DecisionTreeClassifier(max_features='auto', random_state=1797330614),
#  DecisionTreeClassifier(max_features='auto', random_state=1198287528),
#  DecisionTreeClassifier(max_features='auto', random_state=1551964028),
#  DecisionTreeClassifier(max_features='auto', random_state=1656351885),
#  DecisionTreeClassifier(max_features='auto', random_state=1454103412),
#  DecisionTreeClassifier(max_features='auto', random_state=1121398573),
#  DecisionTreeClassifier(max_features='auto', random_state=1107046037),
#  DecisionTreeClassifier(max_features='auto', random_state=1657909179),
#  DecisionTreeClassifier(max_features='auto', random_state=1073011291),
#  DecisionTreeClassifier(max_features='auto', random_state=1388024363),
#  DecisionTreeClassifier(max_features='auto', random_state=169893084),
#  DecisionTreeClassifier(max_features='auto', random_state=355154106),
#  DecisionTreeClassifier(max_features='auto', random_state=1119170270),
#  DecisionTreeClassifier(max_features='auto', random_state=1472573232),
#  DecisionTreeClassifier(max_features='auto', random_state=1134150297),
#  DecisionTreeClassifier(max_features='auto', random_state=2067094447),
#  DecisionTreeClassifier(max_features='auto', random_state=777492178),
#  DecisionTreeClassifier(max_features='auto', random_state=1575186478),
#  DecisionTreeClassifier(max_features='auto', random_state=1398755354),
#  DecisionTreeClassifier(max_features='auto', random_state=992518717),
#  DecisionTreeClassifier(max_features='auto', random_state=2078153564),
#  DecisionTreeClassifier(max_features='auto', random_state=1347004014),
#  DecisionTreeClassifier(max_features='auto', random_state=1275771985),
#  DecisionTreeClassifier(max_features='auto', random_state=1667714234),
#  DecisionTreeClassifier(max_features='auto', random_state=1385090143),
#  DecisionTreeClassifier(max_features='auto', random_state=353103251),
#  DecisionTreeClassifier(max_features='auto', random_state=167544469),
#  DecisionTreeClassifier(max_features='auto', random_state=119935163),
#  DecisionTreeClassifier(max_features='auto', random_state=52537016),
#  DecisionTreeClassifier(max_features='auto', random_state=1607351692),
#  DecisionTreeClassifier(max_features='auto', random_state=153039815),
#  DecisionTreeClassifier(max_features='auto', random_state=1291333520),
#  DecisionTreeClassifier(max_features='auto', random_state=460719456),
#  DecisionTreeClassifier(max_features='auto', random_state=130003003),
#  DecisionTreeClassifier(max_features='auto', random_state=1497291928),
#  DecisionTreeClassifier(max_features='auto', random_state=4622588),
#  DecisionTreeClassifier(max_features='auto', random_state=827000341),
#  DecisionTreeClassifier(max_features='auto', random_state=908493989),
#  DecisionTreeClassifier(max_features='auto', random_state=123867193),
#  DecisionTreeClassifier(max_features='auto', random_state=462972585),
#  DecisionTreeClassifier(max_features='auto', random_state=858842316),
#  DecisionTreeClassifier(max_features='auto', random_state=854052015),
#  DecisionTreeClassifier(max_features='auto', random_state=1131388144),
#  DecisionTreeClassifier(max_features='auto', random_state=1308426268),
#  DecisionTreeClassifier(max_features='auto', random_state=1777989134),
#  DecisionTreeClassifier(max_features='auto', random_state=2125135707),
#  DecisionTreeClassifier(max_features='auto', random_state=1754381386),
#  DecisionTreeClassifier(max_features='auto', random_state=953765467),
#  DecisionTreeClassifier(max_features='auto', random_state=262106741),
#  DecisionTreeClassifier(max_features='auto', random_state=587516863),
#  DecisionTreeClassifier(max_features='auto', random_state=526280075),
#  DecisionTreeClassifier(max_features='auto', random_state=897873239),
#  DecisionTreeClassifier(max_features='auto', random_state=1824556458),
#  DecisionTreeClassifier(max_features='auto', random_state=1567891140),
#  DecisionTreeClassifier(max_features='auto', random_state=870534524),
#  DecisionTreeClassifier(max_features='auto', random_state=40775053),
#  DecisionTreeClassifier(max_features='auto', random_state=722903584),
#  DecisionTreeClassifier(max_features='auto', random_state=829096312),
#  DecisionTreeClassifier(max_features='auto', random_state=858719524),
#  DecisionTreeClassifier(max_features='auto', random_state=1288021241),
#  DecisionTreeClassifier(max_features='auto', random_state=752051958),
#  DecisionTreeClassifier(max_features='auto', random_state=2041348758),
#  DecisionTreeClassifier(max_features='auto', random_state=708849800),
#  DecisionTreeClassifier(max_features='auto', random_state=388163152),
#  DecisionTreeClassifier(max_features='auto', random_state=1029602676),
#  DecisionTreeClassifier(max_features='auto', random_state=856100298),
#  DecisionTreeClassifier(max_features='auto', random_state=1228654401),
#  DecisionTreeClassifier(max_features='auto', random_state=1415312457),
#  DecisionTreeClassifier(max_features='auto', random_state=2085160639),
#  DecisionTreeClassifier(max_features='auto', random_state=1231334754),
#  DecisionTreeClassifier(max_features='auto', random_state=1129124145),
#  DecisionTreeClassifier(max_features='auto', random_state=864383986),
#  DecisionTreeClassifier(max_features='auto', random_state=2042540419),
#  DecisionTreeClassifier(max_features='auto', random_state=1847911806),
#  DecisionTreeClassifier(max_features='auto', random_state=2044083902),
#  DecisionTreeClassifier(max_features='auto', random_state=376512449),
#  DecisionTreeClassifier(max_features='auto', random_state=717285438),
#  DecisionTreeClassifier(max_features='auto', random_state=1545230232),
#  DecisionTreeClassifier(max_features='auto', random_state=732338298),
#  DecisionTreeClassifier(max_features='auto', random_state=775456887),
#  DecisionTreeClassifier(max_features='auto', random_state=1707453412),
#  DecisionTreeClassifier(max_features='auto', random_state=229593365),
#  DecisionTreeClassifier(max_features='auto', random_state=21770397),
#  DecisionTreeClassifier(max_features='auto', random_state=2091620603),
#  DecisionTreeClassifier(max_features='auto', random_state=469688972),
#  DecisionTreeClassifier(max_features='auto', random_state=204178305),
#  DecisionTreeClassifier(max_features='auto', random_state=933625200),
#  DecisionTreeClassifier(max_features='auto', random_state=1294455378),
#  DecisionTreeClassifier(max_features='auto', random_state=1443502227),
#  DecisionTreeClassifier(max_features='auto', random_state=159206274),
#  DecisionTreeClassifier(max_features='auto', random_state=977362561),
#  DecisionTreeClassifier(max_features='auto', random_state=1973847716),
#  DecisionTreeClassifier(max_features='auto', random_state=1634143642),
#  DecisionTreeClassifier(max_features='auto', random_state=1910100943),
#  DecisionTreeClassifier(max_features='auto', random_state=949764220),
#  DecisionTreeClassifier(max_features='auto', random_state=1363244900),
#  DecisionTreeClassifier(max_features='auto', random_state=369354020),
#  DecisionTreeClassifier(max_features='auto', random_state=901441835),
#  DecisionTreeClassifier(max_features='auto', random_state=1417546282),
#  DecisionTreeClassifier(max_features='auto', random_state=1774131261),
#  DecisionTreeClassifier(max_features='auto', random_state=1404289228),
#  DecisionTreeClassifier(max_features='auto', random_state=1216362679),
#  DecisionTreeClassifier(max_features='auto', random_state=96944856),
#  DecisionTreeClassifier(max_features='auto', random_state=189341319),
#  DecisionTreeClassifier(max_features='auto', random_state=1502839028),
#  DecisionTreeClassifier(max_features='auto', random_state=696724985),
#  DecisionTreeClassifier(max_features='auto', random_state=1816928242),
#  DecisionTreeClassifier(max_features='auto', random_state=641932419),
#  DecisionTreeClassifier(max_features='auto', random_state=220310090),
#  DecisionTreeClassifier(max_features='auto', random_state=2000353960),
#  DecisionTreeClassifier(max_features='auto', random_state=1599205980),
#  DecisionTreeClassifier(max_features='auto', random_state=1992692241),
#  DecisionTreeClassifier(max_features='auto', random_state=1371230631),
#  DecisionTreeClassifier(max_features='auto', random_state=135501429),
#  DecisionTreeClassifier(max_features='auto', random_state=2039391685),
#  DecisionTreeClassifier(max_features='auto', random_state=96223658),
#  DecisionTreeClassifier(max_features='auto', random_state=629798492),
#  DecisionTreeClassifier(max_features='auto', random_state=2069808026),
#  DecisionTreeClassifier(max_features='auto', random_state=2029161919),
#  DecisionTreeClassifier(max_features='auto', random_state=904256976),
#  DecisionTreeClassifier(max_features='auto', random_state=289781408),
#  DecisionTreeClassifier(max_features='auto', random_state=1121643809),
#  DecisionTreeClassifier(max_features='auto', random_state=1777419557),
#  DecisionTreeClassifier(max_features='auto', random_state=671314098),
#  DecisionTreeClassifier(max_features='auto', random_state=1828643164),
#  DecisionTreeClassifier(max_features='auto', random_state=853142382)]

# %%
#Previsoes
previsoes = floresta.predict(X_teste)
previsoes
# Out:
# array(['bad', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'good', 'bad',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'bad', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'bad', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'bad', 'good', 'good', 'bad',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'bad', 'bad', 'good',
#        'good', 'good', 'bad', 'good', 'bad', 'good', 'good', 'bad', 'bad',
#        'bad', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'bad', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'bad',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'bad', 'bad'], dtype=object)

# %%
y_teste
# Out:
# array(['good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'bad', 'good', 'good', 'bad', 'good', 'good',
#        'bad', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'bad', 'good', 'good', 'good', 'bad', 'good', 'good', 'bad', 'bad',
#        'good', 'bad', 'good', 'good', 'bad', 'good', 'bad', 'good',
#        'good', 'good', 'good', 'bad', 'bad', 'good', 'good', 'good',
#        'bad', 'bad', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'good', 'bad', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'good', 'good', 'bad', 'bad', 'good', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'bad', 'good', 'good', 'good', 'good', 'good', 'good', 'bad',
#        'good', 'bad', 'good', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'bad', 'bad', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'good', 'bad', 'good',
#        'good', 'bad', 'good', 'good', 'good', 'bad', 'good', 'good',
#        'bad', 'bad', 'bad', 'bad', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'bad', 'good', 'bad', 'bad', 'bad', 'good', 'good', 'good',
#        'good', 'good', 'bad', 'good', 'bad', 'good', 'good', 'good',
#        'good', 'bad', 'bad', 'bad', 'good', 'good', 'good', 'bad', 'good',
#        'bad', 'good', 'good', 'bad', 'bad', 'bad', 'good', 'good', 'bad',
#        'good', 'good', 'good', 'bad', 'good', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'bad', 'good', 'good',
#        'good', 'good', 'good', 'good', 'bad', 'bad', 'good', 'good',
#        'bad', 'bad', 'good', 'bad', 'good', 'good', 'good', 'good', 'bad',
#        'bad', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'good', 'good', 'good',
#        'good', 'bad', 'good', 'bad', 'good', 'bad', 'bad', 'bad', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'bad', 'good',
#        'good', 'good', 'good', 'bad', 'good', 'good', 'good', 'good',
#        'good', 'good', 'good', 'good', 'good', 'bad', 'good', 'bad',
#        'good', 'bad', 'bad'], dtype=object)

# %%
#Matriz de confusão
confusao = confusion_matrix(y_teste, previsoes)
confusao
# Out:
# array([[ 38,  48],
#        [ 14, 200]], dtype=int64)

# %%
#Taxa de acerto
taxa_acerto = accuracy_score(y_teste, previsoes)
taxa_acerto
# Out:
# 0.7933333333333333
